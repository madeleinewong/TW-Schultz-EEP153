# %% [markdown]
# ## Introduction

# %% [markdown]
# In our last project we used data to estimate systems of food demand
# using different datasets.  An output from that project was as set of
# `cfe.Result` objects; these bundle together both data and the results
# from the demand system estimation, and can be used for prediction as
# well.
#
# Here we&rsquo;ll explore some of the uses of the `cfe.Result` class, using
# an instance created using data from the Indian ICRISAT data.
#
# If you don&rsquo;t already have the latest version of the `cfe` package
# installed, grab it, along with some dependencies:

# %%
# !pip install CFEDemands --upgrade --pre
# !pip install xarray --upgrade
# !pip install h5netcdf
# Out:
# Requirement already up-to-date: CFEDemands in /srv/app/venv/lib/python3.6/site-packages
# You are using pip version 9.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already up-to-date: xarray in /srv/app/venv/lib/python3.6/site-packages
# Requirement already up-to-date: numpy>=1.15 in /srv/app/venv/lib/python3.6/site-packages (from xarray)
# Requirement already up-to-date: pandas>=0.25 in /srv/app/venv/lib/python3.6/site-packages (from xarray)
# Requirement already up-to-date: setuptools>=41.2 in /srv/app/venv/lib/python3.6/site-packages (from xarray)
# Requirement already up-to-date: python-dateutil>=2.6.1 in /srv/app/venv/lib/python3.6/site-packages (from pandas>=0.25->xarray)
# Requirement already up-to-date: pytz>=2017.2 in /srv/app/venv/lib/python3.6/site-packages (from pandas>=0.25->xarray)
# Requirement already up-to-date: six>=1.5 in /srv/app/venv/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas>=0.25->xarray)
# You are using pip version 9.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: h5netcdf in /srv/app/venv/lib/python3.6/site-packages
# Requirement already satisfied: h5py in /srv/app/venv/lib/python3.6/site-packages (from h5netcdf)
# Requirement already satisfied: six in /srv/app/venv/lib/python3.6/site-packages (from h5py->h5netcdf)
# Requirement already satisfied: numpy>=1.7 in /srv/app/venv/lib/python3.6/site-packages (from h5py->h5netcdf)
# You are using pip version 9.0.3, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import cfe

cfe.Result?
# Out:
# /usr/lib/python3.6/abc.py:133: FutureWarning: xarray subclass Result should explicitly define __slots__
#   cls = super().__new__(mcls, name, bases, namespace, **kwargs)

# %% [markdown]
# An instance `r` of `cfe.Result` can be made persistent with
# `r.to_dataset('my_result.ds')`, which saves the instance &ldquo;on disk&rdquo; in
# [NetCDF format](https://en.wikipedia.org/wiki/NetCDF), and can be loaded using `cfe.from_dataset`.  We use
# this method below to load data and demand system estimated from the
# Indian ICRISAT data:

# %%
r = cfe.result.from_dataset('Nigeria_small.ds')
# Out:
# /srv/app/venv/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Our focus earlier was on estimation, but the result `r` already has
# encoded in it the results of that estimation.
#
# There are parameters $\alpha$:

# %%
r.get_alpha(as_df=True).dropna()
# Out:
# i
# (Cocoyam, Spinach, etc)                 4.137737
# Agricultural eggs                       4.828057
# Bananas                                 4.752126
# Beef                                    6.097617
# Beer (local and imported)               5.850864
# Bread                                   5.065000
# Brown beans                             5.226534
# Chicken                                 6.381765
# Chocolate drinks                        5.264990
# Cocoyam                                 4.954118
# Condiments,(salt,spices,pepper, etc)    3.358059
# Fish-Dried                              5.577516
# Fish-Fresh                              6.208897
# Fish-Frozen                             5.722683
# Fish-Smoked                             5.389794
# Garden eggs/egg plant                   4.155502
# Gari -Yellow                            5.333468
# Gari-White                              5.244837
# Goat                                    6.398805
# Groundnut oil                           5.270093
# Malt drinks                             4.768953
# Milk powder                             5.114127
# Milk tinned (unsweetened)               5.029506
# Okra-fresh                              4.019283
# Onions                                  4.197350
# Orange/tangerine                        4.392670
# Other vegetables (fresh or canned)      4.238355
# Palm oil                                5.295621
# Pineapples                              4.974817
# Plantains                               5.450495
# Rice-Imported                           5.719247
# Rice-local                              5.431143
# Sachet water                            3.932422
# Seafood (lobster, crab, prawns)         5.415796
# Soft drinks (Coca cola, spirit etc)     4.584848
# Sugar                                   4.079971
# Sweet Potatoes                          4.940481
# Tea                                     4.469507
# Tomato puree(canned)                    4.097380
# Tomatoes                                4.565690
# White beans                             5.031474
# Yam-roots                               5.717074
# Name: alpha, dtype: float64

# %% [markdown]
# Elasticity parameters $\beta$:

# %%
r.get_beta(as_df=True).dropna()
# Out:
# i
# (Cocoyam, Spinach, etc)                 0.264663
# Agricultural eggs                       0.492709
# Bananas                                 0.334000
# Beef                                    0.315412
# Beer (local and imported)               0.327214
# Bread                                   0.346662
# Brown beans                             0.316207
# Chicken                                 0.276107
# Chocolate drinks                        0.541461
# Cocoyam                                 0.241237
# Condiments,(salt,spices,pepper, etc)    0.414796
# Fish-Dried                              0.403277
# Fish-Fresh                              0.386942
# Fish-Frozen                             0.226933
# Fish-Smoked                             0.354824
# Garden eggs/egg plant                   0.240667
# Gari -Yellow                            0.272450
# Gari-White                              0.316419
# Goat                                    0.282581
# Groundnut oil                           0.344536
# Malt drinks                             0.338216
# Milk powder                             0.621545
# Milk tinned (unsweetened)               0.289646
# Okra-fresh                              0.261499
# Onions                                  0.368187
# Orange/tangerine                        0.315993
# Other vegetables (fresh or canned)      0.245179
# Palm oil                                0.310881
# Pineapples                              0.249594
# Plantains                               0.296739
# Rice-Imported                           0.535315
# Rice-local                              0.557892
# Sachet water                            0.403258
# Seafood (lobster, crab, prawns)         0.528855
# Soft drinks (Coca cola, spirit etc)     0.346603
# Sugar                                   0.569223
# Sweet Potatoes                          0.339676
# Tea                                     0.308870
# Tomato puree(canned)                    0.337039
# Tomatoes                                0.328034
# White beans                             0.371580
# Yam-roots                               0.309997
# Name: beta, dtype: float64

# %% [markdown]
# And parameters related to household characteristics $\delta$:

# %%
r.delta.to_dataframe().unstack('k').dropna()
# Out:
#                                          delta                                \
# k                                        F 0-3   F 14-18   F 19-30   F 31-50
# i
# (Cocoyam, Spinach, etc)              -0.023781  0.027689  0.094989  0.110343
# Agricultural eggs                     0.042721  0.048770  0.098147  0.148663
# Bananas                               0.024251  0.035830  0.071993  0.100703
# Beef                                  0.006855  0.067865  0.088548  0.103018
# Beer (local and imported)             0.046941  0.016815  0.016893  0.080541
# Bread                                 0.023225  0.080997  0.096974  0.099630
# Brown beans                           0.028881  0.081007  0.078684  0.109293
# Chicken                              -0.071763 -0.004462  0.060025  0.195275
# Chocolate drinks                      0.070132  0.092243  0.165170  0.115693
# Cocoyam                              -0.046442  0.104503  0.064084  0.025710
# Condiments,(salt,spices,pepper, etc)  0.107599  0.082288  0.056840  0.112495
# Fish-Dried                           -0.020381  0.085493  0.055050  0.062076
# Fish-Fresh                           -0.094961  0.034831  0.107473  0.101196
# Fish-Frozen                           0.035798  0.048886  0.047478  0.073759
# Fish-Smoked                           0.038693  0.136282  0.040907  0.058579
# Garden eggs/egg plant                -0.034263  0.031722  0.020718  0.048421
# Gari -Yellow                         -0.032363  0.031388  0.118099  0.108256
# Gari-White                           -0.027322  0.085809  0.098735  0.125894
# Goat                                 -0.023484 -0.016799  0.107536  0.049343
# Groundnut oil                         0.016858  0.087284  0.059682  0.068239
# Malt drinks                           0.003478  0.049992  0.058493  0.078982
# Milk powder                           0.088818  0.066332  0.141524  0.126835
# Milk tinned (unsweetened)            -0.010725  0.055121  0.027428  0.039411
# Okra-fresh                            0.029346  0.065519  0.092492  0.053412
# Onions                                0.017537  0.075069  0.079954  0.062878
# Orange/tangerine                      0.049942  0.048936  0.043204  0.006788
# Other vegetables (fresh or canned)   -0.025755  0.055946  0.072081  0.028913
# Palm oil                              0.037787  0.090088  0.058209  0.075289
# Pineapples                           -0.021489 -0.014178  0.017237  0.108788
# Plantains                             0.003805  0.109790  0.057469  0.123725
# Rice-Imported                        -0.010551  0.213470  0.169883  0.154974
# Rice-local                            0.033075  0.125565  0.119137  0.084330
# Sachet water                         -0.063939  0.052499  0.064801  0.074672
# Seafood (lobster, crab, prawns)      -0.061463  0.027758  0.163717  0.058583
# Soft drinks (Coca cola, spirit etc)   0.014813  0.071592  0.062311  0.053861
# Sugar                                 0.085182  0.120536  0.128950  0.017301
# Sweet Potatoes                        0.042861  0.020470  0.063971  0.141039
# Tea                                  -0.001488  0.102052 -0.012763  0.110691
# Tomato puree(canned)                 -0.028166  0.096370  0.057285  0.086558
# Tomatoes                              0.039816  0.074168  0.087891  0.100064
# White beans                           0.013274  0.059082  0.096552  0.068464
# Yam-roots                             0.005485  0.084241  0.100080  0.097695
#
#                                                                               \
# k                                        F 4-8     F 51+    F 9-13     M 0-3
# i
# (Cocoyam, Spinach, etc)               0.015007  0.048901  0.021452 -0.016940
# Agricultural eggs                     0.048441  0.048849  0.020054  0.034552
# Bananas                              -0.010054  0.006572  0.036853  0.087191
# Beef                                  0.028480  0.027693  0.044742  0.031357
# Beer (local and imported)             0.034432  0.021043 -0.008684  0.010837
# Bread                                 0.046668  0.013089  0.060806  0.003213
# Brown beans                           0.029328  0.083297  0.067292  0.042174
# Chicken                               0.001326  0.091070  0.006518 -0.065475
# Chocolate drinks                      0.027591  0.035243  0.011240  0.084639
# Cocoyam                               0.061793  0.018195  0.060997 -0.013853
# Condiments,(salt,spices,pepper, etc)  0.082462  0.019536  0.048597  0.038482
# Fish-Dried                            0.014085 -0.027241 -0.003580  0.025389
# Fish-Fresh                           -0.006720  0.053594 -0.061926 -0.083074
# Fish-Frozen                           0.009995  0.054729  0.034365  0.004668
# Fish-Smoked                           0.070487  0.128851  0.028714  0.017261
# Garden eggs/egg plant                 0.025617  0.049835  0.038135  0.024858
# Gari -Yellow                          0.093069 -0.040044  0.054694  0.002290
# Gari-White                           -0.008606  0.023814  0.063419  0.040985
# Goat                                 -0.035660 -0.083726  0.029377  0.036303
# Groundnut oil                         0.021744  0.017518  0.037348  0.045383
# Malt drinks                           0.049129  0.064163  0.022161  0.061383
# Milk powder                           0.026029  0.007136  0.079945  0.093165
# Milk tinned (unsweetened)             0.001813  0.025776  0.012611  0.061620
# Okra-fresh                            0.057568  0.052436  0.031320  0.030216
# Onions                                0.041713  0.037637  0.042463  0.047570
# Orange/tangerine                      0.066712 -0.002760  0.065559  0.071349
# Other vegetables (fresh or canned)    0.014214 -0.007668  0.076505  0.026961
# Palm oil                              0.045923  0.050269  0.061937  0.028195
# Pineapples                           -0.004149  0.067872  0.028218  0.058541
# Plantains                             0.027057  0.099658  0.036744  0.084211
# Rice-Imported                         0.107826  0.035526  0.123423  0.059508
# Rice-local                            0.123012  0.147546  0.080932  0.126638
# Sachet water                         -0.017465 -0.046216  0.012294 -0.040082
# Seafood (lobster, crab, prawns)      -0.017691 -0.101728  0.073951 -0.080318
# Soft drinks (Coca cola, spirit etc)   0.022408 -0.042101  0.047581  0.021450
# Sugar                                 0.120210 -0.067188  0.142751  0.105908
# Sweet Potatoes                        0.019343  0.150611  0.081744  0.032233
# Tea                                  -0.044592  0.090518  0.045326  0.135012
# Tomato puree(canned)                 -0.009960  0.042711  0.043893  0.059545
# Tomatoes                              0.049106  0.078369  0.034203  0.035651
# White beans                           0.079945  0.066782  0.087918  0.074929
# Yam-roots                             0.048482  0.089489  0.057637  0.048243
#
#                                                                               \
# k                                      M 14-18   M 19-30   M 31-50     M 4-8
# i
# (Cocoyam, Spinach, etc)              -0.017215  0.032895  0.033067  0.045847
# Agricultural eggs                     0.053636  0.084221  0.209310  0.096835
# Bananas                               0.074841  0.056436  0.097571  0.014969
# Beef                                  0.067268  0.088596  0.156118  0.040075
# Beer (local and imported)            -0.037233  0.090008  0.113648  0.067073
# Bread                                 0.076229  0.082149  0.148911  0.077405
# Brown beans                           0.078895  0.055726  0.129848  0.095950
# Chicken                              -0.016739  0.046631  0.095953  0.076064
# Chocolate drinks                      0.063775  0.063896  0.164630  0.007797
# Cocoyam                               0.077353  0.048373  0.218153  0.025191
# Condiments,(salt,spices,pepper, etc)  0.074748  0.108106  0.153259  0.054137
# Fish-Dried                            0.049836  0.060312  0.199264  0.008995
# Fish-Fresh                            0.036876  0.038003  0.067573 -0.046422
# Fish-Frozen                           0.062393  0.064411  0.113565  0.017948
# Fish-Smoked                           0.055302  0.042875  0.090371  0.052857
# Garden eggs/egg plant                 0.022445  0.038161  0.108392  0.020383
# Gari -Yellow                          0.063270  0.099990  0.173890  0.081697
# Gari-White                            0.056030  0.057456  0.190343  0.027907
# Goat                                  0.084854  0.072510  0.119583 -0.007823
# Groundnut oil                         0.051483  0.048785  0.134105  0.033797
# Malt drinks                           0.064526  0.038473  0.113829  0.036615
# Milk powder                           0.074568  0.086822  0.233277 -0.016594
# Milk tinned (unsweetened)             0.034586  0.030479  0.062974  0.047417
# Okra-fresh                            0.040731  0.083792  0.110150  0.061569
# Onions                                0.076838  0.072225  0.122375  0.064337
# Orange/tangerine                      0.077146  0.078595  0.108367  0.054287
# Other vegetables (fresh or canned)    0.057070  0.088141  0.053392  0.038146
# Palm oil                              0.070257  0.049671  0.092790  0.068587
# Pineapples                            0.025636  0.048301  0.109066  0.009840
# Plantains                             0.093393  0.080318  0.103872  0.043523
# Rice-Imported                         0.138923  0.131961  0.277047  0.152742
# Rice-local                            0.141380  0.071938  0.230610  0.142830
# Sachet water                          0.061806  0.041966  0.142254  0.026621
# Seafood (lobster, crab, prawns)       0.060650  0.050636  0.159384  0.045985
# Soft drinks (Coca cola, spirit etc)   0.037461  0.072345  0.114707  0.049510
# Sugar                                 0.113737  0.167055  0.209507  0.171881
# Sweet Potatoes                        0.069747  0.064253  0.072542  0.030145
# Tea                                   0.084418 -0.053417  0.146052 -0.109353
# Tomato puree(canned)                  0.011413  0.040396  0.127138  0.049762
# Tomatoes                              0.073747  0.061692  0.100686  0.060698
# White beans                           0.089705  0.086853  0.119772  0.089000
# Yam-roots                             0.106324  0.065004  0.113317  0.056734
#
#
# k                                        M 51+    M 9-13
# i
# (Cocoyam, Spinach, etc)               0.141298 -0.005505
# Agricultural eggs                     0.214793  0.018018
# Bananas                               0.099270  0.041125
# Beef                                  0.157754  0.022819
# Beer (local and imported)             0.053466 -0.007325
# Bread                                 0.175974  0.035565
# Brown beans                           0.138940  0.089248
# Chicken                               0.194257 -0.048039
# Chocolate drinks                      0.167554  0.027564
# Cocoyam                               0.169637  0.013763
# Condiments,(salt,spices,pepper, etc)  0.093409  0.052416
# Fish-Dried                            0.178266  0.018051
# Fish-Fresh                            0.059289 -0.043543
# Fish-Frozen                           0.109814  0.015238
# Fish-Smoked                           0.061429  0.024050
# Garden eggs/egg plant                 0.088736  0.011424
# Gari -Yellow                          0.165120  0.035888
# Gari-White                            0.135647  0.046767
# Goat                                  0.122815  0.010706
# Groundnut oil                         0.088087  0.028083
# Malt drinks                           0.120782  0.016848
# Milk powder                           0.207497  0.044680
# Milk tinned (unsweetened)             0.051796 -0.004631
# Okra-fresh                            0.108578  0.040625
# Onions                                0.098664  0.031032
# Orange/tangerine                      0.135169  0.070500
# Other vegetables (fresh or canned)    0.085122  0.015675
# Palm oil                              0.095184  0.044486
# Pineapples                            0.118915  0.075870
# Plantains                             0.152017  0.049696
# Rice-Imported                         0.226326  0.063119
# Rice-local                            0.147626  0.126741
# Sachet water                          0.094183 -0.042257
# Seafood (lobster, crab, prawns)       0.077967 -0.061051
# Soft drinks (Coca cola, spirit etc)   0.084280  0.011891
# Sugar                                 0.108911  0.126461
# Sweet Potatoes                        0.010980  0.031907
# Tea                                   0.028777  0.069657
# Tomato puree(canned)                  0.070032  0.011288
# Tomatoes                              0.110770  0.024178
# White beans                           0.141000  0.067604
# Yam-roots                             0.138223  0.103894

# %% [markdown]
# The triple of paramters $(\alpha,\beta,\delta)$ completely describes
# the demand system and the corresponding utility function (over the
# goods we observe).

# %% [markdown]
# ## Demands

# %% [markdown]
# As mentioned above, we&rsquo;ve estimated the parameters of a Frischian
# demand system (demands that depend on prices and the households
# marginal utility of expenditures).  But we can *compute* the
# corresponding Marshallian (depends on prices and budget) or Hicksian
# (depends on prices and the level of utility) demands for this same
# population, using the `cfe.Result.demands` method.
#
# Let&rsquo;s compute Marshallian demands.  Start with a choice of budget $x$
# and prices.  We&rsquo;ll use the earliest prices, and focus on
# the first market we&rsquo;re interested in.

# %%
t = r.firstround  # First round
m = r.coords['m'][0] # First market

x = r.get_predicted_expenditures().sum('i')
medianx = x.where(x>0).sel(t=t,m=m).median('j').values # Budget (median household)
# Out:
# /srv/app/venv/lib/python3.6/site-packages/xarray/core/nanops.py:142: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /srv/app/venv/lib/python3.6/site-packages/xarray/core/nputils.py:215: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = getattr(npmodule, name)(values, axis=axis, **kwargs)

# %% [markdown]
# Now compute expenditures on different items.  The object `r` already knows what the estimated
# parameters are, and uses those automatically:

# %%
xbar=r.demands(medianx) # Expenditures given median budget
xbar
# Out:
# i
# (Cocoyam, Spinach, etc)                   25.067268
# Agricultural eggs                        565.395626
# Bananas                                   71.575639
# Beef                                      86.268161
# Beer (local and imported)                 94.020326
# Bread                                     93.796520
# Brown beans                               66.238228
# Chicken                                   53.540855
# Chocolate drinks                        1341.028658
# Cocoyam                                   22.950863
# Condiments,(salt,spices,pepper, etc)     112.800675
# Fish-Dried                               242.120570
# Fish-Fresh                               247.497077
# Fish-Frozen                               22.691006
# Fish-Smoked                              117.129674
# Garden eggs/egg plant                     18.798051
# Gari -Yellow                              38.172886
# Gari-White                                66.810061
# Goat                                      59.062421
# Groundnut oil                             97.899198
# Malt drinks                               75.971012
# Milk powder                             3542.208513
# Milk tinned (unsweetened)                 43.989516
# Okra-fresh                                23.384555
# Onions                                    90.344619
# Orange/tangerine                          50.750381
# Other vegetables (fresh or canned)        20.268438
# Palm oil                                  63.061085
# Pineapples                                25.714824
# Plantains                                 54.682783
# Rice-Imported                           1575.977537
# Rice-local                              1830.630496
# Sachet water                             124.684292
# Seafood (lobster, crab, prawns)         1228.185557
# Soft drinks (Coca cola, spirit etc)       79.354930
# Sugar                                    988.184935
# Sweet Potatoes                            82.048645
# Tea                                       47.566545
# Tomato puree(canned)                      59.676335
# Tomatoes                                  62.383931
# White beans                              128.390849
# Yam-roots                                 71.020279
# Name: quantities, dtype: float64

# %% [markdown]
# So we can compute expenditures, but these are in units of Rupees.
# We can get into physical units (say kilograms) by dividing coconut
# expenditures by the price per kg in a given time and place:

# %%
USE_GOOD = 'Yam-roots'
    
# Reference prices for kgs at time t in market m
ref_price = r.prices.sel(t=t,m=m,u='Kilograms')

r.demands(medianx)[USE_GOOD]/ref_price.loc[USE_GOOD].values
# Out:
# 1.158639760127091

# %% [markdown]
# Now we can trace out demands for a household with median budget but
# varying prices of coconuts (holding other prices fixed):

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Scales of prices:
# Scales of prices:
P = np.linspace(1,10,100).tolist()

plt.plot([r.demands(medianx,p={USE_GOOD:scale})[USE_GOOD]/ref_price.loc[USE_GOOD].values for scale in P],P)

plt.xlabel("%s in Kgs" % USE_GOOD)
plt.ylabel('Price Scale')
# Out:
# Text(0, 0.5, 'Price Scale')

# %% [markdown]
# Let&rsquo;s trace out demands for different budgets:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

X = [medianx*s for s in [.25,.5,1.,2,4]]
for myx in X:
    plt.plot([r.demands(myx,p={USE_GOOD:scale})[USE_GOOD]/ref_price.loc[USE_GOOD].values for scale in P],P)

plt.xlabel("%s in Kgs" % USE_GOOD)
plt.ylabel('Price Scale')
plt.legend(X)
